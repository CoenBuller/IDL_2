# %%
import time

# %%
start=time.time()
print("waiting")
# Out:
# waiting

# %%
while True:
    if time.time()-start>60:
        print ("finish")
        print(time.time()-start)
        break
# Out:
# finish
# 60.000059366226196
